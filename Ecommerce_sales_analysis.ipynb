# %% [markdown]
# <a href="https://colab.research.google.com/github/adityapatil4141/Ecommerce-sales-analysis/blob/main/Ecommerce_sales_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Necessary imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading dataset:
insights = pd.read_csv("/content/drive/MyDrive/work files /computed_insight_success_of_active_sellers.csv")
uc_sorted = pd.read_csv("/content/drive/MyDrive/work files /unique-categories.sorted-by-count.csv")
uc = pd.read_csv("/content/drive/MyDrive/work files /unique-categories.csv")
rating = pd.read_csv("/content/drive/MyDrive/work files /summer-products-with-rating-and-performance_2020-08.csv")

# %%
# Rating dataset:
rating.head()
# Out:
#                                                title  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2  2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3  Hot Summer Cool T-shirt pour les femmes Mode T...
# 4  Femmes Shorts d'été à lacets taille élastique ...
#
#                                           title_orig  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2  2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3  Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4  Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#   currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# 0            EUR         100               0    3.76            54
# 1            EUR       20000               1    3.45          6135
# 2            EUR         100               0    3.57            14
# 3            EUR        5000               1    4.03           579
# 4            EUR         100               1    3.10            20
#
#    rating_five_count  rating_four_count  rating_three_count  rating_two_count  \
# 0               26.0                8.0                10.0               1.0
# 1             2269.0             1027.0              1118.0             644.0
# 2                5.0                4.0                 2.0               0.0
# 3              295.0              119.0                87.0              42.0
# 4                6.0                4.0                 2.0               2.0
#
#    rating_one_count  badges_count  badge_local_product  badge_product_quality  \
# 0               9.0             0                    0                      0
# 1            1077.0             0                    0                      0
# 2               3.0             0                    0                      0
# 3              36.0             0                    0                      0
# 4               6.0             0                    0                      0
#
#    badge_fast_shipping                                               tags  \
# 0                    0  Summer,Fashion,womenunderwearsuit,printedpajam...
# 1                    0  Mini,womens dresses,Summer,Patchwork,fashion d...
# 2                    0  Summer,cardigan,women beachwear,chiffon,Sexy w...
# 3                    0  Summer,Shorts,Cotton,Cotton T Shirt,Sleeve,pri...
# 4                    0  Summer,Plus Size,Lace,Casual pants,Bottom,pant...
#
#   product_color product_variation_size_id  product_variation_inventory  \
# 0         white                         M                           50
# 1         green                        XS                           50
# 2  leopardprint                        XS                            1
# 3         black                         M                           50
# 4        yellow                         S                            1
#
#   shipping_option_name  shipping_option_price  shipping_is_express  \
# 0   Livraison standard                      4                    0
# 1   Livraison standard                      2                    0
# 2   Livraison standard                      3                    0
# 3   Livraison standard                      2                    0
# 4   Livraison standard                      1                    0
#
#    countries_shipped_to  inventory_total  has_urgency_banner  \
# 0                    34               50                 1.0
# 1                    41               50                 1.0
# 2                    36               50                 1.0
# 3                    41               50                 NaN
# 4                    35               50                 1.0
#
#          urgency_text origin_country   merchant_title merchant_name  \
# 0  Quantité limitée !             CN         zgrdejia      zgrdejia
# 1  Quantité limitée !             CN        SaraHouse     sarahouse
# 2  Quantité limitée !             CN           hxt520        hxt520
# 3                 NaN             CN         allenfan      allenfan
# 4  Quantité limitée !             CN  youngpeopleshop   happyhorses
#
#               merchant_info_subtitle  merchant_rating_count  merchant_rating  \
# 0                        (568 notes)                    568         4.128521
# 1  83 % avis positifs (17,752 notes)                  17752         3.899673
# 2     86 % avis positifs (295 notes)                    295         3.989831
# 3                     (23,832 notes)                  23832         4.020435
# 4  85 % avis positifs (14,482 notes)                  14482         4.001588
#
#                 merchant_id  merchant_has_profile_picture  \
# 0  595097d6a26f6e070cb878d1                             0
# 1  56458aa03a698c35c9050988                             0
# 2  5d464a1ffdf7bc44ee933c65                             0
# 3  58cfdefdacb37b556efdff7c                             0
# 4  5ab3b592c3911a095ad5dadb                             0
#
#   merchant_profile_picture                                      product_url  \
# 0                      NaN  https://www.wish.com/c/5e9ae51d43d6a96e303acdb0
# 1                      NaN  https://www.wish.com/c/58940d436a0d3d5da4e95a38
# 2                      NaN  https://www.wish.com/c/5ea10e2c617580260d55310a
# 3                      NaN  https://www.wish.com/c/5cedf17ad1d44c52c59e4aca
# 4                      NaN  https://www.wish.com/c/5ebf5819ebac372b070b0e70
#
#                                      product_picture  \
# 0  https://contestimg.wish.com/api/webimage/5e9ae...
# 1  https://contestimg.wish.com/api/webimage/58940...
# 2  https://contestimg.wish.com/api/webimage/5ea10...
# 3  https://contestimg.wish.com/api/webimage/5cedf...
# 4  https://contestimg.wish.com/api/webimage/5ebf5...
#
#                  product_id   theme crawl_month
# 0  5e9ae51d43d6a96e303acdb0  summer     2020-08
# 1  58940d436a0d3d5da4e95a38  summer     2020-08
# 2  5ea10e2c617580260d55310a  summer     2020-08
# 3  5cedf17ad1d44c52c59e4aca  summer     2020-08
# 4  5ebf5819ebac372b070b0e70  summer     2020-08

# %%
# Unique_categories_sorted dataset:
uc_sorted.head()
# Out:
#    count          keyword
# 0   1321           Summer
# 1   1315  Women's Fashion
# 2   1082          Fashion
# 3    961            Women
# 4    905           Casual

# %%
# Unique categories dataset
uc.head()
# Out:
#                 tag
# 0  #fashion #shorts
# 1  #fashion #tshirt
# 2        #Sport Bra
# 3   #Summer Clothes
# 4        #top #crop

# %%
# Insights dataset:
insights.head()
# Out:
#                  merchantid  listedproducts  totalunitssold  \
# 0  5357bcf2bb72c5504882e889               2          120000
# 1  5708773c3c02161b3f8c7900               5          107100
# 2  5417aada4ad3ab27e954b76c               2          100007
# 3  570f3a713a698c14278bb51e               1          100000
# 4  53082ea15aefb07dfe1f2a4f               1          100000
#
#    meanunitssoldperproduct  rating  merchantratingscount  meanproductprices  \
# 0                  60000.0   4.219              320031.0               9.00
# 1                  21420.0   3.934              139223.0               7.76
# 2                  50004.0   4.053              108048.0               8.00
# 3                 100000.0   3.889               19248.0               5.67
# 4                 100000.0   4.036              366898.0               5.00
#
#    meanretailprices  averagediscount  meandiscount  meanproductratingscount  \
# 0              20.0             54.0          54.0                   8836.0
# 1              34.2             61.0          61.0                   4010.0
# 2               8.0             -1.0          -1.0                   5531.0
# 3              19.0             71.0          71.0                  18393.0
# 4              33.0             85.0          85.0                  13789.0
#
#    totalurgencycount  urgencytextrate
# 0                1.0             50.0
# 1                3.0             60.0
# 2                NaN              NaN
# 3                1.0            100.0
# 4                NaN              NaN

# %%
# All dataset total rows and columns:
print("Insight column shape = ",insights.shape)
print("uc column shape = ",uc.shape)
print("uc.sorted column shape = ",uc_sorted.shape)
print("rating column shape = ",rating.shape)
# Out:
# Insight column shape =  (958, 13)
# uc column shape =  (2620, 1)
# uc.sorted column shape =  (2620, 2)
# rating column shape =  (1573, 43)

# %%
# Code for displaying all coluns while printing the dataset:
pd.set_option('display.max_columns', None)  # This will display all columns

# %%
# Concatenating all dataset:
combined_df = pd.concat([insights, uc, uc_sorted, rating], axis=1)

# %%
combined_df.head()
# Out:
#                  merchantid  listedproducts  totalunitssold  \
# 0  5357bcf2bb72c5504882e889             2.0        120000.0
# 1  5708773c3c02161b3f8c7900             5.0        107100.0
# 2  5417aada4ad3ab27e954b76c             2.0        100007.0
# 3  570f3a713a698c14278bb51e             1.0        100000.0
# 4  53082ea15aefb07dfe1f2a4f             1.0        100000.0
#
#    meanunitssoldperproduct  rating  merchantratingscount  meanproductprices  \
# 0                  60000.0   4.219              320031.0               9.00
# 1                  21420.0   3.934              139223.0               7.76
# 2                  50004.0   4.053              108048.0               8.00
# 3                 100000.0   3.889               19248.0               5.67
# 4                 100000.0   4.036              366898.0               5.00
#
#    meanretailprices  averagediscount  meandiscount  meanproductratingscount  \
# 0              20.0             54.0          54.0                   8836.0
# 1              34.2             61.0          61.0                   4010.0
# 2               8.0             -1.0          -1.0                   5531.0
# 3              19.0             71.0          71.0                  18393.0
# 4              33.0             85.0          85.0                  13789.0
#
#    totalurgencycount  urgencytextrate               tag  count  \
# 0                1.0             50.0  #fashion #shorts   1321
# 1                3.0             60.0  #fashion #tshirt   1315
# 2                NaN              NaN        #Sport Bra   1082
# 3                1.0            100.0   #Summer Clothes    961
# 4                NaN              NaN        #top #crop    905
#
#            keyword                                              title  \
# 0           Summer  2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1  Women's Fashion  SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2          Fashion  2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3            Women  Hot Summer Cool T-shirt pour les femmes Mode T...
# 4           Casual  Femmes Shorts d'été à lacets taille élastique ...
#
#                                           title_orig  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00          14.0
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress   8.00          22.0
# 2  2020 New Arrival Women Spring and Summer Beach...   8.00          43.0
# 3  Hot Summer Cool T Shirt for Women Fashion Tops...   8.00           8.0
# 4  Women Summer Shorts Lace Up Elastic Waistband ...   2.72           3.0
#
#   currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# 0            EUR       100.0             0.0    3.76          54.0
# 1            EUR     20000.0             1.0    3.45        6135.0
# 2            EUR       100.0             0.0    3.57          14.0
# 3            EUR      5000.0             1.0    4.03         579.0
# 4            EUR       100.0             1.0    3.10          20.0
#
#    rating_five_count  rating_four_count  rating_three_count  rating_two_count  \
# 0               26.0                8.0                10.0               1.0
# 1             2269.0             1027.0              1118.0             644.0
# 2                5.0                4.0                 2.0               0.0
# 3              295.0              119.0                87.0              42.0
# 4                6.0                4.0                 2.0               2.0
#
#    rating_one_count  badges_count  badge_local_product  badge_product_quality  \
# 0               9.0           0.0                  0.0                    0.0
# 1            1077.0           0.0                  0.0                    0.0
# 2               3.0           0.0                  0.0                    0.0
# 3              36.0           0.0                  0.0                    0.0
# 4               6.0           0.0                  0.0                    0.0
#
#    badge_fast_shipping                                               tags  \
# 0                  0.0  Summer,Fashion,womenunderwearsuit,printedpajam...
# 1                  0.0  Mini,womens dresses,Summer,Patchwork,fashion d...
# 2                  0.0  Summer,cardigan,women beachwear,chiffon,Sexy w...
# 3                  0.0  Summer,Shorts,Cotton,Cotton T Shirt,Sleeve,pri...
# 4                  0.0  Summer,Plus Size,Lace,Casual pants,Bottom,pant...
#
#   product_color product_variation_size_id  product_variation_inventory  \
# 0         white                         M                         50.0
# 1         green                        XS                         50.0
# 2  leopardprint                        XS                          1.0
# 3         black                         M                         50.0
# 4        yellow                         S                          1.0
#
#   shipping_option_name  shipping_option_price  shipping_is_express  \
# 0   Livraison standard                    4.0                  0.0
# 1   Livraison standard                    2.0                  0.0
# 2   Livraison standard                    3.0                  0.0
# 3   Livraison standard                    2.0                  0.0
# 4   Livraison standard                    1.0                  0.0
#
#    countries_shipped_to  inventory_total  has_urgency_banner  \
# 0                  34.0             50.0                 1.0
# 1                  41.0             50.0                 1.0
# 2                  36.0             50.0                 1.0
# 3                  41.0             50.0                 NaN
# 4                  35.0             50.0                 1.0
#
#          urgency_text origin_country   merchant_title merchant_name  \
# 0  Quantité limitée !             CN         zgrdejia      zgrdejia
# 1  Quantité limitée !             CN        SaraHouse     sarahouse
# 2  Quantité limitée !             CN           hxt520        hxt520
# 3                 NaN             CN         allenfan      allenfan
# 4  Quantité limitée !             CN  youngpeopleshop   happyhorses
#
#               merchant_info_subtitle  merchant_rating_count  merchant_rating  \
# 0                        (568 notes)                  568.0         4.128521
# 1  83 % avis positifs (17,752 notes)                17752.0         3.899673
# 2     86 % avis positifs (295 notes)                  295.0         3.989831
# 3                     (23,832 notes)                23832.0         4.020435
# 4  85 % avis positifs (14,482 notes)                14482.0         4.001588
#
#                 merchant_id  merchant_has_profile_picture  \
# 0  595097d6a26f6e070cb878d1                           0.0
# 1  56458aa03a698c35c9050988                           0.0
# 2  5d464a1ffdf7bc44ee933c65                           0.0
# 3  58cfdefdacb37b556efdff7c                           0.0
# 4  5ab3b592c3911a095ad5dadb                           0.0
#
#   merchant_profile_picture                                      product_url  \
# 0                      NaN  https://www.wish.com/c/5e9ae51d43d6a96e303acdb0
# 1                      NaN  https://www.wish.com/c/58940d436a0d3d5da4e95a38
# 2                      NaN  https://www.wish.com/c/5ea10e2c617580260d55310a
# 3                      NaN  https://www.wish.com/c/5cedf17ad1d44c52c59e4aca
# 4                      NaN  https://www.wish.com/c/5ebf5819ebac372b070b0e70
#
#                                      product_picture  \
# 0  https://contestimg.wish.com/api/webimage/5e9ae...
# 1  https://contestimg.wish.com/api/webimage/58940...
# 2  https://contestimg.wish.com/api/webimage/5ea10...
# 3  https://contestimg.wish.com/api/webimage/5cedf...
# 4  https://contestimg.wish.com/api/webimage/5ebf5...
#
#                  product_id   theme crawl_month
# 0  5e9ae51d43d6a96e303acdb0  summer     2020-08
# 1  58940d436a0d3d5da4e95a38  summer     2020-08
# 2  5ea10e2c617580260d55310a  summer     2020-08
# 3  5cedf17ad1d44c52c59e4aca  summer     2020-08
# 4  5ebf5819ebac372b070b0e70  summer     2020-08

# %%
# New combined dataframe shape:
combined_df.shape
# Out:
# (2620, 59)

# %%
# Dropping unnecessary columns:
combined_df.drop(columns=['merchantid','listedproducts','merchant_has_profile_picture','merchant_profile_picture','product_url','count','title','badges_count','badge_local_product','badge_product_quality','badge_fast_shipping','product_color','merchant_title','merchant_info_subtitle','product_id'],inplace=True)

# %%
# Display new dataset:
combined_df.head()
# Out:
#    totalunitssold  meanunitssoldperproduct  rating  merchantratingscount  \
# 0        120000.0                  60000.0   4.219              320031.0
# 1        107100.0                  21420.0   3.934              139223.0
# 2        100007.0                  50004.0   4.053              108048.0
# 3        100000.0                 100000.0   3.889               19248.0
# 4        100000.0                 100000.0   4.036              366898.0
#
#    meanproductprices  meanretailprices  averagediscount  meandiscount  \
# 0               9.00              20.0             54.0          54.0
# 1               7.76              34.2             61.0          61.0
# 2               8.00               8.0             -1.0          -1.0
# 3               5.67              19.0             71.0          71.0
# 4               5.00              33.0             85.0          85.0
#
#    meanproductratingscount  totalurgencycount  urgencytextrate  \
# 0                   8836.0                1.0             50.0
# 1                   4010.0                3.0             60.0
# 2                   5531.0                NaN              NaN
# 3                  18393.0                1.0            100.0
# 4                  13789.0                NaN              NaN
#
#                 tag          keyword  \
# 0  #fashion #shorts           Summer
# 1  #fashion #tshirt  Women's Fashion
# 2        #Sport Bra          Fashion
# 3   #Summer Clothes            Women
# 4        #top #crop           Casual
#
#                                           title_orig  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00          14.0
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress   8.00          22.0
# 2  2020 New Arrival Women Spring and Summer Beach...   8.00          43.0
# 3  Hot Summer Cool T Shirt for Women Fashion Tops...   8.00           8.0
# 4  Women Summer Shorts Lace Up Elastic Waistband ...   2.72           3.0
#
#   currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# 0            EUR       100.0             0.0    3.76          54.0
# 1            EUR     20000.0             1.0    3.45        6135.0
# 2            EUR       100.0             0.0    3.57          14.0
# 3            EUR      5000.0             1.0    4.03         579.0
# 4            EUR       100.0             1.0    3.10          20.0
#
#    rating_five_count  rating_four_count  rating_three_count  rating_two_count  \
# 0               26.0                8.0                10.0               1.0
# 1             2269.0             1027.0              1118.0             644.0
# 2                5.0                4.0                 2.0               0.0
# 3              295.0              119.0                87.0              42.0
# 4                6.0                4.0                 2.0               2.0
#
#    rating_one_count                                               tags  \
# 0               9.0  Summer,Fashion,womenunderwearsuit,printedpajam...
# 1            1077.0  Mini,womens dresses,Summer,Patchwork,fashion d...
# 2               3.0  Summer,cardigan,women beachwear,chiffon,Sexy w...
# 3              36.0  Summer,Shorts,Cotton,Cotton T Shirt,Sleeve,pri...
# 4               6.0  Summer,Plus Size,Lace,Casual pants,Bottom,pant...
#
#   product_variation_size_id  product_variation_inventory shipping_option_name  \
# 0                         M                         50.0   Livraison standard
# 1                        XS                         50.0   Livraison standard
# 2                        XS                          1.0   Livraison standard
# 3                         M                         50.0   Livraison standard
# 4                         S                          1.0   Livraison standard
#
#    shipping_option_price  shipping_is_express  countries_shipped_to  \
# 0                    4.0                  0.0                  34.0
# 1                    2.0                  0.0                  41.0
# 2                    3.0                  0.0                  36.0
# 3                    2.0                  0.0                  41.0
# 4                    1.0                  0.0                  35.0
#
#    inventory_total  has_urgency_banner        urgency_text origin_country  \
# 0             50.0                 1.0  Quantité limitée !             CN
# 1             50.0                 1.0  Quantité limitée !             CN
# 2             50.0                 1.0  Quantité limitée !             CN
# 3             50.0                 NaN                 NaN             CN
# 4             50.0                 1.0  Quantité limitée !             CN
#
#   merchant_name  merchant_rating_count  merchant_rating  \
# 0      zgrdejia                  568.0         4.128521
# 1     sarahouse                17752.0         3.899673
# 2        hxt520                  295.0         3.989831
# 3      allenfan                23832.0         4.020435
# 4   happyhorses                14482.0         4.001588
#
#                 merchant_id  \
# 0  595097d6a26f6e070cb878d1
# 1  56458aa03a698c35c9050988
# 2  5d464a1ffdf7bc44ee933c65
# 3  58cfdefdacb37b556efdff7c
# 4  5ab3b592c3911a095ad5dadb
#
#                                      product_picture   theme crawl_month
# 0  https://contestimg.wish.com/api/webimage/5e9ae...  summer     2020-08
# 1  https://contestimg.wish.com/api/webimage/58940...  summer     2020-08
# 2  https://contestimg.wish.com/api/webimage/5ea10...  summer     2020-08
# 3  https://contestimg.wish.com/api/webimage/5cedf...  summer     2020-08
# 4  https://contestimg.wish.com/api/webimage/5ebf5...  summer     2020-08

# %%
# Removing few more unwanted columns:
combined_df.drop(columns=['meanunitssoldperproduct','merchant_id','product_picture'],inplace=True)

# %%
# Displaying new dataframe:
combined_df.shape
# Out:
# (2620, 41)

# %%
# Nulvalues count
null_values = combined_df.isnull().sum()

# %%
# Converting null values count in list
null_values_list=null_values.index.to_list()

# %%
# Information about new dataframe:
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2620 entries, 0 to 2619
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   totalunitssold               958 non-null    float64
#  1   rating                       958 non-null    float64
#  2   merchantratingscount         958 non-null    float64
#  3   meanproductprices            958 non-null    float64
#  4   meanretailprices             958 non-null    float64
#  5   averagediscount              958 non-null    float64
#  6   meandiscount                 958 non-null    float64
#  7   meanproductratingscount      958 non-null    float64
#  8   totalurgencycount            391 non-null    float64
#  9   urgencytextrate              391 non-null    float64
#  10  tag                          2620 non-null   object
#  11  keyword                      2620 non-null   object
#  12  title_orig                   1573 non-null   object
#  13  price                        1573 non-null   float64
#  14  retail_price                 1573 non-null   float64
#  15  currency_buyer               1573 non-null   object
#  16  units_sold                   1573 non-null   float64
#  17  uses_ad_boosts               1573 non-null   float64
#  18  rating                       1573 non-null   float64
#  19  rating_count                 1573 non-null   float64
#  20  rating_five_count            1528 non-null   float64
#  21  rating_four_count            1528 non-null   float64
#  22  rating_three_count           1528 non-null   float64
#  23  rating_two_count             1528 non-null   float64
#  24  rating_one_count             1528 non-null   float64
#  25  tags                         1573 non-null   object
#  26  product_variation_size_id    1559 non-null   object
#  27  product_variation_inventory  1573 non-null   float64
#  28  shipping_option_name         1573 non-null   object
#  29  shipping_option_price        1573 non-null   float64
#  30  shipping_is_express          1573 non-null   float64
#  31  countries_shipped_to         1573 non-null   float64
#  32  inventory_total              1573 non-null   float64
#  33  has_urgency_banner           473 non-null    float64
#  34  urgency_text                 473 non-null    object
#  35  origin_country               1556 non-null   object
#  36  merchant_name                1569 non-null   object
#  37  merchant_rating_count        1573 non-null   float64
#  38  merchant_rating              1573 non-null   float64
#  39  theme                        1573 non-null   object
#  40  crawl_month                  1573 non-null   object
# dtypes: float64(29), object(12)
# memory usage: 839.3+ KB

# %%
 # Total null value:
 combined_df.isnull().sum()
# Out:
# totalunitssold                 1662
# rating                         1662
# merchantratingscount           1662
# meanproductprices              1662
# meanretailprices               1662
# averagediscount                1662
# meandiscount                   1662
# meanproductratingscount        1662
# totalurgencycount              2229
# urgencytextrate                2229
# tag                               0
# keyword                           0
# title_orig                     1047
# price                          1047
# retail_price                   1047
# currency_buyer                 1047
# units_sold                     1047
# uses_ad_boosts                 1047
# rating                         1047
# rating_count                   1047
# rating_five_count              1092
# rating_four_count              1092
# rating_three_count             1092
# rating_two_count               1092
# rating_one_count               1092
# tags                           1047
# product_variation_size_id      1061
# product_variation_inventory    1047
# shipping_option_name           1047
# shipping_option_price          1047
# shipping_is_express            1047
# countries_shipped_to           1047
# inventory_total                1047
# has_urgency_banner             2147
# urgency_text                   2147
# origin_country                 1064
# merchant_name                  1051
# merchant_rating_count          1047
# merchant_rating                1047
# theme                          1047
# crawl_month                    1047
# dtype: int64

# %%
# For loop for filling all null values:
for i in null_values_list:
  combined_df[i]= combined_df[i].fillna(0)

# %%
# Checking for duplicates:
combined_df.duplicated().sum()
# Out:
# 0

# %%
# Heatmap for visualizing correalation:
plt.figure(figsize=(15,9))
sns.heatmap(abs(combined_df.corr()),cmap='Reds',annot=True,fmt='.2f',linewidths=3)
# Out:
# <ipython-input-213-dea5f8af0ed0>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(abs(combined_df.corr()),cmap='Reds',annot=True,fmt='.2f',linewidths=3)
# <Axes: >

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2620 entries, 0 to 2619
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   totalunitssold               2620 non-null   float64
#  1   rating                       2620 non-null   float64
#  2   merchantratingscount         2620 non-null   float64
#  3   meanproductprices            2620 non-null   float64
#  4   meanretailprices             2620 non-null   float64
#  5   averagediscount              2620 non-null   float64
#  6   meandiscount                 2620 non-null   float64
#  7   meanproductratingscount      2620 non-null   float64
#  8   totalurgencycount            2620 non-null   float64
#  9   urgencytextrate              2620 non-null   float64
#  10  tag                          2620 non-null   object
#  11  keyword                      2620 non-null   object
#  12  title_orig                   2620 non-null   object
#  13  price                        2620 non-null   float64
#  14  retail_price                 2620 non-null   float64
#  15  currency_buyer               2620 non-null   object
#  16  units_sold                   2620 non-null   float64
#  17  uses_ad_boosts               2620 non-null   float64
#  18  rating                       2620 non-null   float64
#  19  rating_count                 2620 non-null   float64
#  20  rating_five_count            2620 non-null   float64
#  21  rating_four_count            2620 non-null   float64
#  22  rating_three_count           2620 non-null   float64
#  23  rating_two_count             2620 non-null   float64
#  24  rating_one_count             2620 non-null   float64
#  25  tags                         2620 non-null   object
#  26  product_variation_size_id    2620 non-null   object
#  27  product_variation_inventory  2620 non-null   float64
#  28  shipping_option_name         2620 non-null   object
#  29  shipping_option_price        2620 non-null   float64
#  30  shipping_is_express          2620 non-null   float64
#  31  countries_shipped_to         2620 non-null   float64
#  32  inventory_total              2620 non-null   float64
#  33  has_urgency_banner           2620 non-null   float64
#  34  urgency_text                 2620 non-null   object
#  35  origin_country               2620 non-null   object
#  36  merchant_name                2620 non-null   object
#  37  merchant_rating_count        2620 non-null   float64
#  38  merchant_rating              2620 non-null   float64
#  39  theme                        2620 non-null   object
#  40  crawl_month                  2620 non-null   object
# dtypes: float64(29), object(12)
# memory usage: 839.3+ KB

# %%
combined_df['tag']=combined_df['tag'].replace(0,np.nan)
combined_df['keyword']=combined_df['keyword'].replace(0,np.nan)
combined_df['title_orig']=combined_df['title_orig'].replace(0,np.nan)
combined_df['currency_buyer']=combined_df['currency_buyer'].replace(0,np.nan)
combined_df['tags']=combined_df['tags'].replace(0,np.nan)
combined_df['product_variation_size_id']=combined_df['product_variation_size_id'].replace(0,np.nan)
combined_df['shipping_option_name']=combined_df['shipping_option_name'].replace(0,np.nan)
combined_df['origin_country']=combined_df['origin_country'].replace(0,np.nan)
combined_df['merchant_name']=combined_df['merchant_name'].replace(0,np.nan)
combined_df['theme']=combined_df['theme'].replace(0,'summer')

# %%
# variance inflation factor:
from statsmodels.stats.outliers_influence import variance_inflation_factor
def evaluate_vif(x):
  vif_data = pd.DataFrame()
  vif_data['variables'] = x.columns
  vif_data['vif'] = [variance_inflation_factor(x.values,i)for i in range(x.shape[1])]
  return vif_data

# %%
evaluate_vif(combined_df[[i for i in combined_df.describe().columns]])
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/stats/outliers_influence.py:198: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#                       variables           vif
# 0                totalunitssold  3.679865e+00
# 1                        rating           inf
# 2                        rating           inf
# 3          merchantratingscount  1.184704e+00
# 4             meanproductprices  7.426158e+00
# 5              meanretailprices  4.518585e+00
# 6               averagediscount  1.288539e+05
# 7                  meandiscount  1.287683e+05
# 8       meanproductratingscount  3.263718e+00
# 9             totalurgencycount  3.941440e+00
# 10              urgencytextrate  3.484992e+00
# 11                        price  2.505042e+01
# 12                 retail_price  1.797250e+00
# 13                   units_sold  6.865399e+00
# 14               uses_ad_boosts  1.837408e+00
# 15                       rating           inf
# 16                       rating           inf
# 17                 rating_count           inf
# 18            rating_five_count           inf
# 19            rating_four_count           inf
# 20           rating_three_count           inf
# 21             rating_two_count           inf
# 22             rating_one_count           inf
# 23  product_variation_inventory  4.016371e+00
# 24        shipping_option_price  2.955573e+01
# 25          shipping_is_express  1.190964e+00
# 26         countries_shipped_to  5.278943e+00
# 27              inventory_total  1.974650e+02
# 28           has_urgency_banner  1.445131e+00
# 29        merchant_rating_count  1.251535e+00
# 30              merchant_rating  2.466196e+02

# %%
# top 5 products with highest no. of rating
top_products = combined_df.groupby('title_orig')['rating_count'].sum().reset_index().sort_values(by='rating_count',ascending=False).set_index('title_orig').head()
print(top_products)
top_products.plot(kind='barh')
# plt.xticks(rotation=40)
# Out:
#                                                     rating_count
# title_orig
# Women Stretchy Camisole Spaghetti Strap Long Ta...       20744.0
# Women's stripes Lined up double up tankini top ...       20502.0
# Summer Women Sexy White Embroidery Lace Crop To...       18463.0
# Women's Summer Sexy Sleeveless Turtleneck Mini ...       18393.0
# 2018 New Fashion Women's Tops Sexy Strappy Slee...       17980.0
# <Axes: ylabel='title_orig'>

# %%
combined_df.head(2)
# Out:
#    totalunitssold  rating  merchantratingscount  meanproductprices  \
# 0        120000.0   4.219              320031.0               9.00
# 1        107100.0   3.934              139223.0               7.76
#
#    meanretailprices  averagediscount  meandiscount  meanproductratingscount  \
# 0              20.0             54.0          54.0                   8836.0
# 1              34.2             61.0          61.0                   4010.0
#
#    totalurgencycount  urgencytextrate               tag          keyword  \
# 0                1.0             50.0  #fashion #shorts           Summer
# 1                3.0             60.0  #fashion #tshirt  Women's Fashion
#
#                                           title_orig  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0          14.0
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress    8.0          22.0
#
#   currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# 0            EUR       100.0             0.0    3.76          54.0
# 1            EUR     20000.0             1.0    3.45        6135.0
#
#    rating_five_count  rating_four_count  rating_three_count  rating_two_count  \
# 0               26.0                8.0                10.0               1.0
# 1             2269.0             1027.0              1118.0             644.0
#
#    rating_one_count                                               tags  \
# 0               9.0  Summer,Fashion,womenunderwearsuit,printedpajam...
# 1            1077.0  Mini,womens dresses,Summer,Patchwork,fashion d...
#
#   product_variation_size_id  product_variation_inventory shipping_option_name  \
# 0                         M                         50.0   Livraison standard
# 1                        XS                         50.0   Livraison standard
#
#    shipping_option_price  shipping_is_express  countries_shipped_to  \
# 0                    4.0                  0.0                  34.0
# 1                    2.0                  0.0                  41.0
#
#    inventory_total  has_urgency_banner        urgency_text origin_country  \
# 0             50.0                 1.0  Quantité limitée !             CN
# 1             50.0                 1.0  Quantité limitée !             CN
#
#   merchant_name  merchant_rating_count  merchant_rating   theme crawl_month
# 0      zgrdejia                  568.0         4.128521  summer     2020-08
# 1     sarahouse                17752.0         3.899673  summer     2020-08

# %%
unitssold_product = combined_df.groupby('title_orig')['units_sold'].sum().reset_index().sort_values(by='units_sold',ascending=False).set_index('title_orig').head()
print(unitssold_product)
plt.figure(figsize=(10,6))
unitssold_product.plot(kind='barh')
# Out:
#                                                     units_sold
# title_orig
# Women Lace Short Sleeve Long Tops Blouse Shirt ...    100000.0
# Womens Summer Red White and Blue Chiffon Short-...    100000.0
# 2018 New Fashion Women's Tops Sexy Strappy Slee...    100000.0
# New Aeeival Women Clothing Long Sleeve Autumn W...    100000.0
# Women's Summer Sexy Sleeveless Turtleneck Mini ...    100000.0
# <Axes: ylabel='title_orig'>

# %%
combined_df.uses_ad_boosts=combined_df.uses_ad_boosts.astype('int64')

# %%
ad_unit_sold = combined_df.groupby('uses_ad_boosts')['units_sold'].sum().reset_index().set_index('uses_ad_boosts')
ad_unit_sold.plot(kind='bar')
# Out:
# <Axes: xlabel='uses_ad_boosts'>

# %%
ad_unit_sold
# Out:
#                 units_sold
# uses_ad_boosts
# 0                3987435.0
# 1                2837820.0

# %%
combined_df.theme.value_counts()
# Out:
# summer    2620
# Name: theme, dtype: int64
